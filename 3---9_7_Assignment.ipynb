# %% [markdown]
# <h1> <b>Q. Make the graph of temperature and humidity from the 'nyc_weather.csv' file...</b> </h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('nyc_weather.csv')

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    01/01/16           38        23        52                 30.03
# 1    01/02/16           36        18        46                 30.02
# 2    01/03/16           40        21        47                 29.86
# 3    01/04/16           25         9        44                 30.05
# 4    01/05/16           20        -3        41                 30.57
# 5    01/06/16           33         4        35                 30.50
# 6    01/07/16           39        11        33                 30.28
# 7    01/08/16           39        29        64                 30.20
# 8    01/09/16           44        38        77                 30.16
# 9    01/10/16           50        46        71                 29.59
# 10   01/11/16           33         8        37                 29.92
# 11   01/12/16           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
# EST                     31 non-null object
# Temperature             31 non-null int64
# DewPoint                31 non-null int64
# Humidity                31 non-null int64
# Sea Level PressureIn    31 non-null float64
# VisibilityMiles         31 non-null int64
# WindSpeedMPH            28 non-null float64
# PrecipitationIn         31 non-null object
# CloudCover              31 non-null int64
# Events                  9 non-null object
# WindDirDegrees          31 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.3+ KB

# %%
temp = df['Temperature']
humidity = df['Humidity']

# %%
color = np.random.rand(31)

# %%
plt.scatter(temp,humidity, c = color )
plt.xlabel('Temperature----->')
plt.ylabel('Humidity------->')
plt.title("Temp. & Humidity Graph")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
